# %%
import os
import numpy as np
from PIL import Image, ImageDraw
import shutil
import csv

# Define parameters
image_size = (512, 512)  # Size of the images
num_samples = 200  # Number of samples for each shape
max_translation = 20  # Maximum translation in pixels
max_rotation = 10  # Maximum rotation in degrees
max_shear = 5  # Maximum shear in degrees
max_scale = 1.1  # Maximum scale factor

# Create a function to generate star images
def generate_star_images(num_samples, output_dir="Dataset/synthetic_shape_dataset", num_images=1):
    # delete all files and subdirectories in the output directory
    if os.path.exists(output_dir):
        shutil.rmtree(output_dir)
    os.makedirs(output_dir, exist_ok=True)

    # Create a csv file to store the affine parameters (training and validation sets)
    affine_parameters_path_train = os.path.join(output_dir, "dataset_shape_synth_train.csv")
    with open(affine_parameters_path_train, "w", newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["source", "target", "M1", "M2", "M3", "M4", "M5", "M6"])
    affine_parameters_path_test = os.path.join(output_dir, "dataset_shape_synth_test.csv")
    with open(affine_parameters_path_test, "w", newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["source", "target", "M1", "M2", "M3", "M4", "M5", "M6"])

    # save 10% of the images for testing
    num_test = int(num_samples * 0.1)
    num_train = num_samples - num_test
    print(f"Generating {num_images*num_train} training images and {num_images*num_test} testing images")
    print(f"Location of the images: {output_dir}")
    print(f"Saving affine parameters to {affine_parameters_path_train} and {affine_parameters_path_test}")

    # Generate images
    for i in range(num_samples):
        for j in range(num_images):
            # Create a fixed-size image
            image = Image.new("L", image_size, 0)
            draw = ImageDraw.Draw(image)
            
            # Draw a star centered in the image
            center = (image_size[0] // 2, image_size[1] // 2)
            size = np.random.randint(150, min(image_size) // 2)
            points = []
            for _ in range(10):
                angle = np.random.uniform(0, 2 * np.pi)
                x = int(center[0] + size * np.cos(angle))
                y = int(center[1] + size * np.sin(angle))
                points.append((x, y))
            draw.polygon(points, fill=np.random.randint(100, 256))
            
            # Generate random affine transformations
            translation = (
                np.random.randint(-max_translation, max_translation + 1),
                np.random.randint(-max_translation, max_translation + 1),
            )
            rotation = np.random.uniform(-max_rotation, max_rotation)
            shear = np.random.uniform(-max_shear, max_shear)
            scale = np.random.uniform(1.0, max_scale)
            
            # Apply affine transformations
            affine_matrix = [
                scale * np.cos(np.radians(rotation + shear)), -scale * np.sin(np.radians(rotation + shear)), translation[0],
                scale * np.sin(np.radians(rotation)), scale * np.cos(np.radians(rotation)), translation[1]
            ]
            transformed_image = image.transform(image_size, Image.AFFINE, affine_matrix)
            
            # Save original image
            original_image_path = os.path.join(output_dir, f"star_{i+1}_original.png")
            image.save(original_image_path)
            
            # add noise to the transformed image and save it
            transformed_image = transformed_image.point(lambda x: x + np.random.randint(-10, 10))
            transformed_image_path = os.path.join(output_dir, f"star_{i+1}_transformed_{j}.png")
            transformed_image.save(transformed_image_path)
            
            M = np.array(affine_matrix).flatten()
            # Save affine parameters to a csv file (one line per image pair)
            if i < num_test:
                with open(affine_parameters_path_test, "a", newline='') as csvfile:
                    writer = csv.writer(csvfile)
                    writer.writerow([original_image_path, transformed_image_path, M[0], M[1], M[2], M[3], M[4], M[5]])
            else:
                with open(affine_parameters_path_train, "a", newline='') as csvfile:
                    writer = csv.writer(csvfile)
                    writer.writerow([original_image_path, transformed_image_path, M[0], M[1], M[2], M[3], M[4], M[5]])
    print("Done!")
    print("")

# Generate star images
output_dir = "Dataset/synthetic_shape_dataset"  # Output directory
generate_star_images(num_samples, output_dir=output_dir, num_images=1)

# Generate star images with 2 transformations
output_dir = "Dataset/synthetic_shape_dataset_multiple"  # Output directory
generate_star_images(num_samples, output_dir=output_dir, num_images=2)
# Out:
# Generating 180 training images and 20 testing images
# Location of the images: Dataset/synthetic_shape_dataset
# Saving affine parameters to Dataset/synthetic_shape_dataset/dataset_shape_synth_train.csv and Dataset/synthetic_shape_dataset/dataset_shape_synth_test.csv
# Done!
#
# Generating 360 training images and 40 testing images
# Location of the images: Dataset/synthetic_shape_dataset_multiple
# Saving affine parameters to Dataset/synthetic_shape_dataset_multiple/dataset_shape_synth_train.csv and Dataset/synthetic_shape_dataset_multiple/dataset_shape_synth_test.csv
# Done!

# %%
# grab images in the directory
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2

# grab images in the directory
images = glob.glob('Dataset/synthetic_shape_dataset/*.png')
len(images)

# sort images
images.sort()
for i in range(len(images)):
    print(images[i])
# Out:
# Dataset/synthetic_shape_dataset/star_100_original.png
# Dataset/synthetic_shape_dataset/star_100_transformed.png
# Dataset/synthetic_shape_dataset/star_101_original.png
# Dataset/synthetic_shape_dataset/star_101_transformed.png
# Dataset/synthetic_shape_dataset/star_102_original.png
# Dataset/synthetic_shape_dataset/star_102_transformed.png
# Dataset/synthetic_shape_dataset/star_103_original.png
# Dataset/synthetic_shape_dataset/star_103_transformed.png
# Dataset/synthetic_shape_dataset/star_104_original.png
# Dataset/synthetic_shape_dataset/star_104_transformed.png
# Dataset/synthetic_shape_dataset/star_105_original.png
# Dataset/synthetic_shape_dataset/star_105_transformed.png
# Dataset/synthetic_shape_dataset/star_106_original.png
# Dataset/synthetic_shape_dataset/star_106_transformed.png
# Dataset/synthetic_shape_dataset/star_107_original.png
# Dataset/synthetic_shape_dataset/star_107_transformed.png
# Dataset/synthetic_shape_dataset/star_108_original.png
# Dataset/synthetic_shape_dataset/star_108_transformed.png
# Dataset/synthetic_shape_dataset/star_109_original.png
# Dataset/synthetic_shape_dataset/star_109_transformed.png
# Dataset/synthetic_shape_dataset/star_10_original.png
# Dataset/synthetic_shape_dataset/star_10_transformed.png
# Dataset/synthetic_shape_dataset/star_110_original.png
# Dataset/synthetic_shape_dataset/star_110_transformed.png
# Dataset/synthetic_shape_dataset/star_111_original.png
# Dataset/synthetic_shape_dataset/star_111_transformed.png
# Dataset/synthetic_shape_dataset/star_112_original.png
# Dataset/synthetic_shape_dataset/star_112_transformed.png
# Dataset/synthetic_shape_dataset/star_113_original.png
# Dataset/synthetic_shape_dataset/star_113_transformed.png
# Dataset/synthetic_shape_dataset/star_114_original.png
# Dataset/synthetic_shape_dataset/star_114_transformed.png
# Dataset/synthetic_shape_dataset/star_115_original.png
# Dataset/synthetic_shape_dataset/star_115_transformed.png
# Dataset/synthetic_shape_dataset/star_116_original.png
# Dataset/synthetic_shape_dataset/star_116_transformed.png
# Dataset/synthetic_shape_dataset/star_117_original.png
# Dataset/synthetic_shape_dataset/star_117_transformed.png
# Dataset/synthetic_shape_dataset/star_118_original.png
# Dataset/synthetic_shape_dataset/star_118_transformed.png
# Dataset/synthetic_shape_dataset/star_119_original.png
# Dataset/synthetic_shape_dataset/star_119_transformed.png
# Dataset/synthetic_shape_dataset/star_11_original.png
# Dataset/synthetic_shape_dataset/star_11_transformed.png
# Dataset/synthetic_shape_dataset/star_120_original.png
# Dataset/synthetic_shape_dataset/star_120_transformed.png
# Dataset/synthetic_shape_dataset/star_121_original.png
# Dataset/synthetic_shape_dataset/star_121_transformed.png
# Dataset/synthetic_shape_dataset/star_122_original.png
# Dataset/synthetic_shape_dataset/star_122_transformed.png
# Dataset/synthetic_shape_dataset/star_123_original.png
# Dataset/synthetic_shape_dataset/star_123_transformed.png
# Dataset/synthetic_shape_dataset/star_124_original.png
# Dataset/synthetic_shape_dataset/star_124_transformed.png
# Dataset/synthetic_shape_dataset/star_125_original.png
# Dataset/synthetic_shape_dataset/star_125_transformed.png
# Dataset/synthetic_shape_dataset/star_126_original.png
# Dataset/synthetic_shape_dataset/star_126_transformed.png
# Dataset/synthetic_shape_dataset/star_127_original.png
# Dataset/synthetic_shape_dataset/star_127_transformed.png
# Dataset/synthetic_shape_dataset/star_128_original.png
# Dataset/synthetic_shape_dataset/star_128_transformed.png
# Dataset/synthetic_shape_dataset/star_129_original.png
# Dataset/synthetic_shape_dataset/star_129_transformed.png
# Dataset/synthetic_shape_dataset/star_12_original.png
# Dataset/synthetic_shape_dataset/star_12_transformed.png
# Dataset/synthetic_shape_dataset/star_130_original.png
# Dataset/synthetic_shape_dataset/star_130_transformed.png
# Dataset/synthetic_shape_dataset/star_131_original.png
# Dataset/synthetic_shape_dataset/star_131_transformed.png
# Dataset/synthetic_shape_dataset/star_132_original.png
# Dataset/synthetic_shape_dataset/star_132_transformed.png
# Dataset/synthetic_shape_dataset/star_133_original.png
# Dataset/synthetic_shape_dataset/star_133_transformed.png
# Dataset/synthetic_shape_dataset/star_134_original.png
# Dataset/synthetic_shape_dataset/star_134_transformed.png
# Dataset/synthetic_shape_dataset/star_135_original.png
# Dataset/synthetic_shape_dataset/star_135_transformed.png
# Dataset/synthetic_shape_dataset/star_136_original.png
# Dataset/synthetic_shape_dataset/star_136_transformed.png
# Dataset/synthetic_shape_dataset/star_137_original.png
# Dataset/synthetic_shape_dataset/star_137_transformed.png
# Dataset/synthetic_shape_dataset/star_138_original.png
# Dataset/synthetic_shape_dataset/star_138_transformed.png
# Dataset/synthetic_shape_dataset/star_139_original.png
# Dataset/synthetic_shape_dataset/star_139_transformed.png
# Dataset/synthetic_shape_dataset/star_13_original.png
# Dataset/synthetic_shape_dataset/star_13_transformed.png
# Dataset/synthetic_shape_dataset/star_140_original.png
# Dataset/synthetic_shape_dataset/star_140_transformed.png
# Dataset/synthetic_shape_dataset/star_141_original.png
# Dataset/synthetic_shape_dataset/star_141_transformed.png
# Dataset/synthetic_shape_dataset/star_142_original.png
# Dataset/synthetic_shape_dataset/star_142_transformed.png
# Dataset/synthetic_shape_dataset/star_143_original.png
# Dataset/synthetic_shape_dataset/star_143_transformed.png
# Dataset/synthetic_shape_dataset/star_144_original.png
# Dataset/synthetic_shape_dataset/star_144_transformed.png
# Dataset/synthetic_shape_dataset/star_145_original.png
# Dataset/synthetic_shape_dataset/star_145_transformed.png
# Dataset/synthetic_shape_dataset/star_146_original.png
# Dataset/synthetic_shape_dataset/star_146_transformed.png
# Dataset/synthetic_shape_dataset/star_147_original.png
# Dataset/synthetic_shape_dataset/star_147_transformed.png
# Dataset/synthetic_shape_dataset/star_148_original.png
# Dataset/synthetic_shape_dataset/star_148_transformed.png
# Dataset/synthetic_shape_dataset/star_149_original.png
# Dataset/synthetic_shape_dataset/star_149_transformed.png
# Dataset/synthetic_shape_dataset/star_14_original.png
# Dataset/synthetic_shape_dataset/star_14_transformed.png
# Dataset/synthetic_shape_dataset/star_150_original.png
# Dataset/synthetic_shape_dataset/star_150_transformed.png
# Dataset/synthetic_shape_dataset/star_151_original.png
# Dataset/synthetic_shape_dataset/star_151_transformed.png
# Dataset/synthetic_shape_dataset/star_152_original.png
# Dataset/synthetic_shape_dataset/star_152_transformed.png
# Dataset/synthetic_shape_dataset/star_153_original.png
# Dataset/synthetic_shape_dataset/star_153_transformed.png
# Dataset/synthetic_shape_dataset/star_154_original.png
# Dataset/synthetic_shape_dataset/star_154_transformed.png
# Dataset/synthetic_shape_dataset/star_155_original.png
# Dataset/synthetic_shape_dataset/star_155_transformed.png
# Dataset/synthetic_shape_dataset/star_156_original.png
# Dataset/synthetic_shape_dataset/star_156_transformed.png
# Dataset/synthetic_shape_dataset/star_157_original.png
# Dataset/synthetic_shape_dataset/star_157_transformed.png
# Dataset/synthetic_shape_dataset/star_158_original.png
# Dataset/synthetic_shape_dataset/star_158_transformed.png
# Dataset/synthetic_shape_dataset/star_159_original.png
# Dataset/synthetic_shape_dataset/star_159_transformed.png
# Dataset/synthetic_shape_dataset/star_15_original.png
# Dataset/synthetic_shape_dataset/star_15_transformed.png
# Dataset/synthetic_shape_dataset/star_160_original.png
# Dataset/synthetic_shape_dataset/star_160_transformed.png
# Dataset/synthetic_shape_dataset/star_161_original.png
# Dataset/synthetic_shape_dataset/star_161_transformed.png
# Dataset/synthetic_shape_dataset/star_162_original.png
# Dataset/synthetic_shape_dataset/star_162_transformed.png
# Dataset/synthetic_shape_dataset/star_163_original.png
# Dataset/synthetic_shape_dataset/star_163_transformed.png
# Dataset/synthetic_shape_dataset/star_164_original.png
# Dataset/synthetic_shape_dataset/star_164_transformed.png
# Dataset/synthetic_shape_dataset/star_165_original.png
# Dataset/synthetic_shape_dataset/star_165_transformed.png
# Dataset/synthetic_shape_dataset/star_166_original.png
# Dataset/synthetic_shape_dataset/star_166_transformed.png
# Dataset/synthetic_shape_dataset/star_167_original.png
# Dataset/synthetic_shape_dataset/star_167_transformed.png
# Dataset/synthetic_shape_dataset/star_168_original.png
# Dataset/synthetic_shape_dataset/star_168_transformed.png
# Dataset/synthetic_shape_dataset/star_169_original.png
# Dataset/synthetic_shape_dataset/star_169_transformed.png
# Dataset/synthetic_shape_dataset/star_16_original.png
# Dataset/synthetic_shape_dataset/star_16_transformed.png
# Dataset/synthetic_shape_dataset/star_170_original.png
# Dataset/synthetic_shape_dataset/star_170_transformed.png
# Dataset/synthetic_shape_dataset/star_171_original.png
# Dataset/synthetic_shape_dataset/star_171_transformed.png
# Dataset/synthetic_shape_dataset/star_172_original.png
# Dataset/synthetic_shape_dataset/star_172_transformed.png
# Dataset/synthetic_shape_dataset/star_173_original.png
# Dataset/synthetic_shape_dataset/star_173_transformed.png
# Dataset/synthetic_shape_dataset/star_174_original.png
# Dataset/synthetic_shape_dataset/star_174_transformed.png
# Dataset/synthetic_shape_dataset/star_175_original.png
# Dataset/synthetic_shape_dataset/star_175_transformed.png
# Dataset/synthetic_shape_dataset/star_176_original.png
# Dataset/synthetic_shape_dataset/star_176_transformed.png
# Dataset/synthetic_shape_dataset/star_177_original.png
# Dataset/synthetic_shape_dataset/star_177_transformed.png
# Dataset/synthetic_shape_dataset/star_178_original.png
# Dataset/synthetic_shape_dataset/star_178_transformed.png
# Dataset/synthetic_shape_dataset/star_179_original.png
# Dataset/synthetic_shape_dataset/star_179_transformed.png
# Dataset/synthetic_shape_dataset/star_17_original.png
# Dataset/synthetic_shape_dataset/star_17_transformed.png
# Dataset/synthetic_shape_dataset/star_180_original.png
# Dataset/synthetic_shape_dataset/star_180_transformed.png
# Dataset/synthetic_shape_dataset/star_181_original.png
# Dataset/synthetic_shape_dataset/star_181_transformed.png
# Dataset/synthetic_shape_dataset/star_182_original.png
# Dataset/synthetic_shape_dataset/star_182_transformed.png
# Dataset/synthetic_shape_dataset/star_183_original.png
# Dataset/synthetic_shape_dataset/star_183_transformed.png
# Dataset/synthetic_shape_dataset/star_184_original.png
# Dataset/synthetic_shape_dataset/star_184_transformed.png
# Dataset/synthetic_shape_dataset/star_185_original.png
# Dataset/synthetic_shape_dataset/star_185_transformed.png
# Dataset/synthetic_shape_dataset/star_186_original.png
# Dataset/synthetic_shape_dataset/star_186_transformed.png
# Dataset/synthetic_shape_dataset/star_187_original.png
# Dataset/synthetic_shape_dataset/star_187_transformed.png
# Dataset/synthetic_shape_dataset/star_188_original.png
# Dataset/synthetic_shape_dataset/star_188_transformed.png
# Dataset/synthetic_shape_dataset/star_189_original.png
# Dataset/synthetic_shape_dataset/star_189_transformed.png
# Dataset/synthetic_shape_dataset/star_18_original.png
# Dataset/synthetic_shape_dataset/star_18_transformed.png
# Dataset/synthetic_shape_dataset/star_190_original.png
# Dataset/synthetic_shape_dataset/star_190_transformed.png
# Dataset/synthetic_shape_dataset/star_191_original.png
# Dataset/synthetic_shape_dataset/star_191_transformed.png
# Dataset/synthetic_shape_dataset/star_192_original.png
# Dataset/synthetic_shape_dataset/star_192_transformed.png
# Dataset/synthetic_shape_dataset/star_193_original.png
# Dataset/synthetic_shape_dataset/star_193_transformed.png
# Dataset/synthetic_shape_dataset/star_194_original.png
# Dataset/synthetic_shape_dataset/star_194_transformed.png
# Dataset/synthetic_shape_dataset/star_195_original.png
# Dataset/synthetic_shape_dataset/star_195_transformed.png
# Dataset/synthetic_shape_dataset/star_196_original.png
# Dataset/synthetic_shape_dataset/star_196_transformed.png
# Dataset/synthetic_shape_dataset/star_197_original.png
# Dataset/synthetic_shape_dataset/star_197_transformed.png
# Dataset/synthetic_shape_dataset/star_198_original.png
# Dataset/synthetic_shape_dataset/star_198_transformed.png
# Dataset/synthetic_shape_dataset/star_199_original.png
# Dataset/synthetic_shape_dataset/star_199_transformed.png
# Dataset/synthetic_shape_dataset/star_19_original.png
# Dataset/synthetic_shape_dataset/star_19_transformed.png
# Dataset/synthetic_shape_dataset/star_1_original.png
# Dataset/synthetic_shape_dataset/star_1_transformed.png
# Dataset/synthetic_shape_dataset/star_200_original.png
# Dataset/synthetic_shape_dataset/star_200_transformed.png
# Dataset/synthetic_shape_dataset/star_20_original.png
# Dataset/synthetic_shape_dataset/star_20_transformed.png
# Dataset/synthetic_shape_dataset/star_21_original.png
# Dataset/synthetic_shape_dataset/star_21_transformed.png
# Dataset/synthetic_shape_dataset/star_22_original.png
# Dataset/synthetic_shape_dataset/star_22_transformed.png
# Dataset/synthetic_shape_dataset/star_23_original.png
# Dataset/synthetic_shape_dataset/star_23_transformed.png
# Dataset/synthetic_shape_dataset/star_24_original.png
# Dataset/synthetic_shape_dataset/star_24_transformed.png
# Dataset/synthetic_shape_dataset/star_25_original.png
# Dataset/synthetic_shape_dataset/star_25_transformed.png
# Dataset/synthetic_shape_dataset/star_26_original.png
# Dataset/synthetic_shape_dataset/star_26_transformed.png
# Dataset/synthetic_shape_dataset/star_27_original.png
# Dataset/synthetic_shape_dataset/star_27_transformed.png
# Dataset/synthetic_shape_dataset/star_28_original.png
# Dataset/synthetic_shape_dataset/star_28_transformed.png
# Dataset/synthetic_shape_dataset/star_29_original.png
# Dataset/synthetic_shape_dataset/star_29_transformed.png
# Dataset/synthetic_shape_dataset/star_2_original.png
# Dataset/synthetic_shape_dataset/star_2_transformed.png
# Dataset/synthetic_shape_dataset/star_30_original.png
# Dataset/synthetic_shape_dataset/star_30_transformed.png
# Dataset/synthetic_shape_dataset/star_31_original.png
# Dataset/synthetic_shape_dataset/star_31_transformed.png
# Dataset/synthetic_shape_dataset/star_32_original.png
# Dataset/synthetic_shape_dataset/star_32_transformed.png
# Dataset/synthetic_shape_dataset/star_33_original.png
# Dataset/synthetic_shape_dataset/star_33_transformed.png
# Dataset/synthetic_shape_dataset/star_34_original.png
# Dataset/synthetic_shape_dataset/star_34_transformed.png
# Dataset/synthetic_shape_dataset/star_35_original.png
# Dataset/synthetic_shape_dataset/star_35_transformed.png
# Dataset/synthetic_shape_dataset/star_36_original.png
# Dataset/synthetic_shape_dataset/star_36_transformed.png
# Dataset/synthetic_shape_dataset/star_37_original.png
# Dataset/synthetic_shape_dataset/star_37_transformed.png
# Dataset/synthetic_shape_dataset/star_38_original.png
# Dataset/synthetic_shape_dataset/star_38_transformed.png
# Dataset/synthetic_shape_dataset/star_39_original.png
# Dataset/synthetic_shape_dataset/star_39_transformed.png
# Dataset/synthetic_shape_dataset/star_3_original.png
# Dataset/synthetic_shape_dataset/star_3_transformed.png
# Dataset/synthetic_shape_dataset/star_40_original.png
# Dataset/synthetic_shape_dataset/star_40_transformed.png
# Dataset/synthetic_shape_dataset/star_41_original.png
# Dataset/synthetic_shape_dataset/star_41_transformed.png
# Dataset/synthetic_shape_dataset/star_42_original.png
# Dataset/synthetic_shape_dataset/star_42_transformed.png
# Dataset/synthetic_shape_dataset/star_43_original.png
# Dataset/synthetic_shape_dataset/star_43_transformed.png
# Dataset/synthetic_shape_dataset/star_44_original.png
# Dataset/synthetic_shape_dataset/star_44_transformed.png
# Dataset/synthetic_shape_dataset/star_45_original.png
# Dataset/synthetic_shape_dataset/star_45_transformed.png
# Dataset/synthetic_shape_dataset/star_46_original.png
# Dataset/synthetic_shape_dataset/star_46_transformed.png
# Dataset/synthetic_shape_dataset/star_47_original.png
# Dataset/synthetic_shape_dataset/star_47_transformed.png
# Dataset/synthetic_shape_dataset/star_48_original.png
# Dataset/synthetic_shape_dataset/star_48_transformed.png
# Dataset/synthetic_shape_dataset/star_49_original.png
# Dataset/synthetic_shape_dataset/star_49_transformed.png
# Dataset/synthetic_shape_dataset/star_4_original.png
# Dataset/synthetic_shape_dataset/star_4_transformed.png
# Dataset/synthetic_shape_dataset/star_50_original.png
# Dataset/synthetic_shape_dataset/star_50_transformed.png
# Dataset/synthetic_shape_dataset/star_51_original.png
# Dataset/synthetic_shape_dataset/star_51_transformed.png
# Dataset/synthetic_shape_dataset/star_52_original.png
# Dataset/synthetic_shape_dataset/star_52_transformed.png
# Dataset/synthetic_shape_dataset/star_53_original.png
# Dataset/synthetic_shape_dataset/star_53_transformed.png
# Dataset/synthetic_shape_dataset/star_54_original.png
# Dataset/synthetic_shape_dataset/star_54_transformed.png
# Dataset/synthetic_shape_dataset/star_55_original.png
# Dataset/synthetic_shape_dataset/star_55_transformed.png
# Dataset/synthetic_shape_dataset/star_56_original.png
# Dataset/synthetic_shape_dataset/star_56_transformed.png
# Dataset/synthetic_shape_dataset/star_57_original.png
# Dataset/synthetic_shape_dataset/star_57_transformed.png
# Dataset/synthetic_shape_dataset/star_58_original.png
# Dataset/synthetic_shape_dataset/star_58_transformed.png
# Dataset/synthetic_shape_dataset/star_59_original.png
# Dataset/synthetic_shape_dataset/star_59_transformed.png
# Dataset/synthetic_shape_dataset/star_5_original.png
# Dataset/synthetic_shape_dataset/star_5_transformed.png
# Dataset/synthetic_shape_dataset/star_60_original.png
# Dataset/synthetic_shape_dataset/star_60_transformed.png
# Dataset/synthetic_shape_dataset/star_61_original.png
# Dataset/synthetic_shape_dataset/star_61_transformed.png
# Dataset/synthetic_shape_dataset/star_62_original.png
# Dataset/synthetic_shape_dataset/star_62_transformed.png
# Dataset/synthetic_shape_dataset/star_63_original.png
# Dataset/synthetic_shape_dataset/star_63_transformed.png
# Dataset/synthetic_shape_dataset/star_64_original.png
# Dataset/synthetic_shape_dataset/star_64_transformed.png
# Dataset/synthetic_shape_dataset/star_65_original.png
# Dataset/synthetic_shape_dataset/star_65_transformed.png
# Dataset/synthetic_shape_dataset/star_66_original.png
# Dataset/synthetic_shape_dataset/star_66_transformed.png
# Dataset/synthetic_shape_dataset/star_67_original.png
# Dataset/synthetic_shape_dataset/star_67_transformed.png
# Dataset/synthetic_shape_dataset/star_68_original.png
# Dataset/synthetic_shape_dataset/star_68_transformed.png
# Dataset/synthetic_shape_dataset/star_69_original.png
# Dataset/synthetic_shape_dataset/star_69_transformed.png
# Dataset/synthetic_shape_dataset/star_6_original.png
# Dataset/synthetic_shape_dataset/star_6_transformed.png
# Dataset/synthetic_shape_dataset/star_70_original.png
# Dataset/synthetic_shape_dataset/star_70_transformed.png
# Dataset/synthetic_shape_dataset/star_71_original.png
# Dataset/synthetic_shape_dataset/star_71_transformed.png
# Dataset/synthetic_shape_dataset/star_72_original.png
# Dataset/synthetic_shape_dataset/star_72_transformed.png
# Dataset/synthetic_shape_dataset/star_73_original.png
# Dataset/synthetic_shape_dataset/star_73_transformed.png
# Dataset/synthetic_shape_dataset/star_74_original.png
# Dataset/synthetic_shape_dataset/star_74_transformed.png
# Dataset/synthetic_shape_dataset/star_75_original.png
# Dataset/synthetic_shape_dataset/star_75_transformed.png
# Dataset/synthetic_shape_dataset/star_76_original.png
# Dataset/synthetic_shape_dataset/star_76_transformed.png
# Dataset/synthetic_shape_dataset/star_77_original.png
# Dataset/synthetic_shape_dataset/star_77_transformed.png
# Dataset/synthetic_shape_dataset/star_78_original.png
# Dataset/synthetic_shape_dataset/star_78_transformed.png
# Dataset/synthetic_shape_dataset/star_79_original.png
# Dataset/synthetic_shape_dataset/star_79_transformed.png
# Dataset/synthetic_shape_dataset/star_7_original.png
# Dataset/synthetic_shape_dataset/star_7_transformed.png
# Dataset/synthetic_shape_dataset/star_80_original.png
# Dataset/synthetic_shape_dataset/star_80_transformed.png
# Dataset/synthetic_shape_dataset/star_81_original.png
# Dataset/synthetic_shape_dataset/star_81_transformed.png
# Dataset/synthetic_shape_dataset/star_82_original.png
# Dataset/synthetic_shape_dataset/star_82_transformed.png
# Dataset/synthetic_shape_dataset/star_83_original.png
# Dataset/synthetic_shape_dataset/star_83_transformed.png
# Dataset/synthetic_shape_dataset/star_84_original.png
# Dataset/synthetic_shape_dataset/star_84_transformed.png
# Dataset/synthetic_shape_dataset/star_85_original.png
# Dataset/synthetic_shape_dataset/star_85_transformed.png
# Dataset/synthetic_shape_dataset/star_86_original.png
# Dataset/synthetic_shape_dataset/star_86_transformed.png
# Dataset/synthetic_shape_dataset/star_87_original.png
# Dataset/synthetic_shape_dataset/star_87_transformed.png
# Dataset/synthetic_shape_dataset/star_88_original.png
# Dataset/synthetic_shape_dataset/star_88_transformed.png
# Dataset/synthetic_shape_dataset/star_89_original.png
# Dataset/synthetic_shape_dataset/star_89_transformed.png
# Dataset/synthetic_shape_dataset/star_8_original.png
# Dataset/synthetic_shape_dataset/star_8_transformed.png
# Dataset/synthetic_shape_dataset/star_90_original.png
# Dataset/synthetic_shape_dataset/star_90_transformed.png
# Dataset/synthetic_shape_dataset/star_91_original.png
# Dataset/synthetic_shape_dataset/star_91_transformed.png
# Dataset/synthetic_shape_dataset/star_92_original.png
# Dataset/synthetic_shape_dataset/star_92_transformed.png
# Dataset/synthetic_shape_dataset/star_93_original.png
# Dataset/synthetic_shape_dataset/star_93_transformed.png
# Dataset/synthetic_shape_dataset/star_94_original.png
# Dataset/synthetic_shape_dataset/star_94_transformed.png
# Dataset/synthetic_shape_dataset/star_95_original.png
# Dataset/synthetic_shape_dataset/star_95_transformed.png
# Dataset/synthetic_shape_dataset/star_96_original.png
# Dataset/synthetic_shape_dataset/star_96_transformed.png
# Dataset/synthetic_shape_dataset/star_97_original.png
# Dataset/synthetic_shape_dataset/star_97_transformed.png
# Dataset/synthetic_shape_dataset/star_98_original.png
# Dataset/synthetic_shape_dataset/star_98_transformed.png
# Dataset/synthetic_shape_dataset/star_99_original.png
# Dataset/synthetic_shape_dataset/star_99_transformed.png
# Dataset/synthetic_shape_dataset/star_9_original.png
# Dataset/synthetic_shape_dataset/star_9_transformed.png

# %%
# use SIFT to detect and extract features from the image 
# and plot the images in pairs with the keypoints overlaid
# sift = cv2.SIFT_create()

# for i in range(0, 100, 2):
#     fig, ax = plt.subplots(1, 2, figsize=(20, 10))
#     img1 = cv2.imread(images[i], 0)
#     img2 = cv2.imread(images[i+1], 0)
#     kp, des = sift.detectAndCompute(img1, None)
#     img = cv2.drawKeypoints(img1, kp, None)
#     ax[0].imshow(img)
#     ax[0].axis('off')
#     ax[0].set_title(f'#{int(i/2+1)} Original Image')

#     kp, des = sift.detectAndCompute(img2, None)
#     img = cv2.drawKeypoints(img2, kp, None)
#     ax[1].imshow(img)
#     ax[1].axis('off')
#     ax[1].set_title(f'Transformed Image')
#     os.makedirs('Dataset/synthetic_shape_dataset/plot', exist_ok=True)
#     plt.savefig(f'Dataset/synthetic_shape_dataset/plot/{int(i/2+1)}.png')
#     plt.close()
